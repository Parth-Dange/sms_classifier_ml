# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spam.csv', encoding=('ISO-8859-1'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 4833  ham                      I hope your pee burns tonite.        NaN
# 5447  ham              So that takes away some money worries        NaN
# 1773  ham          I'm not coming over, do whatever you want        NaN
# 284   ham  Yeah I think my usual guy's still passed out f...        NaN
# 331   ham  Maybe i could get book out tomo then return it...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 4833        NaN        NaN
# 5447        NaN        NaN
# 1773        NaN        NaN
# 284         NaN        NaN
# 331         NaN        NaN

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3', 'Unnamed: 4'], inplace= True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 2817   ham  Thk some of em find wtc too far... Weiyi not g...
# 5531   ham  Compliments to you. Was away from the system. ...
# 5178  spam  SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 a...
# 2303   ham  Should I tell my friend not to come round til ...
# 5387   ham  I will be gentle baby! Soon you will be taking...

# %%
df.rename(columns={'v1':'target', 'v2':'text'}, inplace=True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 4308    ham  He dint tell anything. He is angry on me that ...
# 5432    ham                             Thanx a lot 4 ur help!
# 287     ham  hi baby im cruisin with my girl friend what r ...
# 3664    ham              Ha... U jus ate honey ar? So sweet...
# 2192    ham  Congrats ! Treat pending.i am not on mail for ...

# %%
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep= 'first')

# %%
df.shape
# Out:
# (5169, 2)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.sample(5)
# Out:
#       target                                               text
# 3217       0    Don know:)this week i'm going to tirunelvai da.
# 1327       1  Ur balance is now å£500. Ur next question is: ...
# 977        0  Dont hesitate. You know this is the second tim...
# 1176       0  Did he say how fantastic I am by any chance, o...
# 3732       0              Old Orchard near univ. How about you?

# %%
df.target
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 5567    1
# 5568    0
# 5569    0
# 5570    0
# 5571    0
# Name: target, Length: 5169, dtype: int32

# %% [markdown]
# ## EDA

# %%
df['target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt 
plt.pie(df['target'].value_counts(), labels = ['ham', 'spam'], autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x22808e62150>,
# ...
#  [Text(-1.0144997251399075, 0.4251944351600247, 'ham'),
#   Text(1.014499764949479, -0.4251943401757036, 'spam')],
#  [Text(-0.5533634864399495, 0.23192423736001344, '87.37'),
#   Text(0.5533635081542612, -0.23192418555038377, '12.63')])

# %%
#data is imabalanced

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Parth
# [nltk_data]     Dange\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters']= df['text'].apply(len)

# %%
df['num_words']= df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df['num_sentences']= df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.describe()
# Out:
#             target  num_characters    num_words  num_sentences
# count  5169.000000     5169.000000  5169.000000    5169.000000
# mean      0.126330       78.977945    18.455794       1.965564
# std       0.332253       58.236293    13.324758       1.448541
# min       0.000000        2.000000     1.000000       1.000000
# 25%       0.000000       36.000000     9.000000       1.000000
# 50%       0.000000       60.000000    15.000000       1.000000
# 75%       0.000000      117.000000    26.000000       2.000000
# max       1.000000      910.000000   220.000000      38.000000

# %%
df[df['target'] == 0][['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
df[df['target'] == 1][['num_characters', 'num_words', 'num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
sns.histplot(df[df['target'] ==0]['num_characters'])
sns.histplot(df[df['target'] ==1]['num_characters'], color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.pairplot(df, hue='target')

# %% [markdown]
# ## data preprosessing
# 1. lowercase
# 2. tokenisation and removing special characters
# 3. removing stop words and punctuations
# 4. stemming

# %%
import nltk
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import PorterStemmer
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Parth
# [nltk_data]     Dange\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def transform_text(text):
    text =text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
            
    text = y[:]  # cloning is very important to save the list into string format
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]  # cloning is very important to save the list into string format
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    
        
    return " ".join(y)

# %%
transform_text('lectures are interesting but you are not $$')
# Out:
# 'lectur interest'

# %%
df['transfromed_text']  = df['text'].apply(transform_text)

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences  \
# 0                111         24              2
# 1                 29          8              2
# 2                155         37              2
# ...

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
wc = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10)

# %%
spam_wc = wc.generate(df[df['target']==1]['transfromed_text'].str.cat(sep = " "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target']==0]['transfromed_text'].str.cat(sep = " "))
plt.imshow(ham_wc)

# %%
spam_scorpus = []
for msg in df[df['target']==1]['transfromed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences  \
# 0                111         24              2
# 1                 29          8              2
# 2                155         37              2
# ...

# %%
# !pip install collection

# %%
from collections import Counter
DATA = pd.DataFrame(Counter(spam_corpus).most_common(30))
x_values = [pair[0] for pair in Counter(spam_corpus).most_common(30)]
y_values = [pair[1] for pair in Counter(spam_corpus).most_common(30)]

# %%
plt.figure(figsize=(20,4))
plt.bar(x_values, y_values)
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Bar Plot of Spam Corpus Data')
plt.show()

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences  \
# 0                111         24              2
# 1                 29          8              2
# 2                155         37              2
# ...

# %%
# Out:
# 0

# %%
# Out:
# []

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences  \
# 0                111         24              2
# 1                 29          8              2
# 2                155         37              2
# ...

# %%
ham_corpus = []
for msg in df[df['target']==0]['transfromed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
ham_corpus
# Out:
# ['go',
#  'jurong',
#  'point',
#  'crazi',
#  'avail',
#  'bugi',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  'cine',
#  'got',
#  'amor',
#  'wat',
#  'ok',
#  'lar',
#  'joke',
#  'wif',
#  'u',
#  'oni',
#  'u',
#  'dun',
#  'say',
#  'earli',
#  'hor',
#  'u',
#  'c',
#  'alreadi',
#  'say',
#  'nah',
#  'think',
#  'goe',
#  'usf',
#  'live',
#  'around',
#  'though',
#  'even',
#  'brother',
#  'like',
#  'speak',
#  'treat',
#  'like',
#  'aid',
#  'patent',
#  'per',
#  'request',
#  'mell',
#  'oru',
#  'minnaminungint',
#  'nurungu',
#  'vettam',
#  'set',
#  'callertun',
#  'caller',
#  'press',
#  '9',
#  'copi',
#  'friend',
#  'callertun',
#  'gon',
#  'na',
#  'home',
#  'soon',
#  'want',
#  'talk',
#  'stuff',
#  'anymor',
#  'tonight',
#  'k',
#  'cri',
#  'enough',
#  'today',
#  'search',
#  'right',
#  'word',
#  'thank',
#  'breather',
#  'promis',
#  'wont',
#  'take',
#  'help',
#  'grant',
#  'fulfil',
#  'promis',
#  'wonder',
# ...

# %%
from collections import Counter
pd.DataFrame(Counter(ham_corpus).most_common(30))
x_value = [pair[0] for pair in Counter(ham_corpus).most_common(30)]
y_value = [pair[1] for pair in Counter(ham_corpus).most_common(30)]

# %%
plt.figure(figsize=(20,6))
plt.bar(x_value, y_value)
plt.show()

# %%
Counter(ham_corpus).most_common(30)
# Out:
# [('u', 883),
#  ('go', 404),
#  ('get', 349),
#  ('gt', 288),
#  ('lt', 287),
#  ('2', 284),
#  ('come', 275),
#  ('got', 236),
#  ('know', 236),
#  ('like', 234),
#  ('call', 233),
#  ('time', 219),
#  ('ok', 217),
#  ('love', 216),
#  ('good', 213),
#  ('want', 208),
#  ('ur', 197),
#  ('day', 190),
#  ('need', 170),
#  ('one', 165),
#  ('lor', 159),
#  ('4', 156),
#  ('home', 152),
#  ('think', 149),
#  ('see', 147),
#  ('take', 143),
#  ('still', 143),
#  ('da', 142),
#  ('tell', 133),
#  ('make', 129)]
